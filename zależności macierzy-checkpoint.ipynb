# %%
def y(x):
    
    y=np.array(x).reshape(2,2)    
    det=np.linalg.det(x)
    
    z=(1/det)*np.array((x[1,1], -x[0,1], -x[1,0], x[0,0])).reshape(2,2)
    a=(-1/x[1,0])*np.array([x[1,1], 1, det, x[0,0]]).reshape(2,2)
    b=(1/x[0,1])*np.array([-x[0,0], 1, det, -x[1,1]]).reshape(2,2)
    h=(1/x[0,0])*np.array([1, -x[0,1], x[1,0], det]).reshape(2,2)
    g=(1/x[1,1])*np.array([det, x[0,1], -x[1,0], 1]).reshape(2,2)

    return "Twoja macierz:",y,"Wyznacznik:",det,"Z", z, 'A', a, 'B', b, 'H', h, 'G', g

def z(x):
    
    z=np.array(x).reshape(2,2)
    det=np.linalg.det(x)
    
    y=(1/det)*np.array([x[1,1], -x[0,1], -x[1,0], x[0,0]]).reshape(2,2)
    a=(1/x[1,0])*np.array([x[0,0], det, 1, x[1,1]]).reshape(2,2)
    b=(1/x[0,1])*np.array([x[1,1], -det, -1, x[0,0]]).reshape(2,2)
    h=(1/x[1,1])*np.array([det, x[0,1], -x[1,0], 1]).reshape(2,2)
    g=(1/x[0,0])*np.array([1, -x[0,1], x[1,0], det]).reshape(2,2)

    return "Twoja macierz:",z,"Wyznacznik:",det,"Y", y, 'A', a, 'B', b, 'H', h, 'G', g

def a(x):
    
    a=np.array(x).reshape(2,2)
    det=np.linalg.det(x)
    
    y=(1/x[0,1])*np.array([x[1,1], -det, -1, x[0,0]]).reshape(2,2)
    z=(1/x[1,0])*np.array([x[0,0], det, 1, x[1,1]]).reshape(2,2)
    b=(1/det)*np.array([x[1,1], -x[0,1], -x[1,0], x[0,0]]).reshape(2,2)
    h=(1/x[1,1])*np.array([x[0,1], det, -1, x[1,0]]).reshape(2,2)
    g=(1/x[0,0])*np.array([x[1,0], -det, 1, x[0,1]]).reshape(2,2)

    
    return "Twoja macierz:",a,"Wyznacznik:",det,"Z", z, 'Y', y, 'B', b, 'H', h, 'G', g

def b(x):
    
    b=np.array(x).reshape(2,2)
    det=np.linalg.det(x)
    
    y=(1/x[0,1])*np.array([-x[1,1], 1, det, -x[1,1]]).reshape(2,2)
    z=(-1/x[1,0])*np.array([x[1,1], 1, det, x[0,0]]).reshape(2,2)
    a=(1/det)*np.array([x[1,1], -x[0,1], -x[1,0], x[0,0]]).reshape(2,2)
    h=(-1/x[0,0])*np.array([x[0,1], -1, det, x[1,0]]).reshape(2,2)
    g=(-1/x[1,1])*np.array([x[1,0], 1, -det, x[0,1]]).reshape(2,2)

    return "Twoja macierz:",b,"Wyznacznik:",det,"Z", z, 'Y', y, 'A', a, 'H', h, 'G', g

def h(x):
    h=np.array(x).reshape(2,2)
    det=np.linalg.det(x)
    
    y=(1/x[0,0])*np.array([1, -x[0,1], x[1,0], det]).reshape(2,2)
    z=(1/x[1,1])*np.array([det, x[0,1], -x[1,0], 1]).reshape(2,2)
    a=(-1/x[1,0])*np.array([det, x[0,0], x[1,1], 1]).reshape(2,2)
    b=(1/x[0,1])*np.array([1, -x[0,0], -x[1,1], det]).reshape(2,2)
    g=(1/det)*np.array([x[1,1], -x[0,1], -x[1,0], x[0,0]]).reshape(2,2)

    return "Twoja macierz:",h,"Wyznacznik:",det,"Z", z, 'Y', y, 'A', a, 'B', b, 'G', g

def g(x):
    g=np.array(x).reshape(2,2)
    det=np.linalg.det(x)
    
    y=(1/x[1,1])*np.array([det, x[0,1], -x[1,0], 1]).reshape(2,2)
    z=(1/x[0,0])*np.array([1, -x[0,1], x[1,0], det]).reshape(2,2)
    a=(1/x[1,0])*np.array([1, x[1,1], x[0,0], det]).reshape(2,2)
    b=(1/x[0,1])*np.array([-det, x[1,1], x[0,0], -1]).reshape(2,2)
    g=(1/det)*np.array([x[1,1], -x[0,1], -x[1,0], x[0,0]]).reshape(2,2)

    return "Twoja macierz:",g,"Wyznacznik:",det,"Z", z, 'Y', y, 'A', a, 'B', b, 'H', h

# %%
import numpy as np


your_matrix=input("Wprowadź elementy macierzy(oddzielone spacją):" ).split() #pobiera dane rozdziealjąc je
your_matrix=np.array(your_matrix, dtype='f').reshape(2,2)

kind=input("Wprowadź rodzaj macierzy:" )

kinds_matrix={'y':y(your_matrix), 'z':z(your_matrix), 'a':a(your_matrix), 'b':b(your_matrix), 'h':h(your_matrix), 'g':g(your_matrix)}

kinds_matrix.get(kind)

# def kinds_matrix(x):
#     if(x=='y'): return y()
#     if(x=='z'): return z()
#     if(x=='a')
#     if(x=='y')
#     if(x=='y')
#     if(x=='y')
# Out:
# Wprowadź elementy macierzy(oddzielone spacją): 1 2 3 4
# Wprowadź rodzaj macierzy: y
# ('Twoja macierz:',
#  array([[1., 2.],
#         [3., 4.]], dtype=float32),
#  'Wyznacznik:',
#  -2.0,
#  'Z',
#  array([[-2. ,  1. ],
#         [ 1.5, -0.5]], dtype=float32),
#  'A',
#  array([[-1.33333333, -0.33333333],
#         [ 0.66666667, -0.33333333]]),
#  'B',
#  array([[-0.5,  0.5],
#         [-1. , -2. ]]),
#  'H',
#  array([[ 1., -2.],
#         [ 3., -2.]]),
#  'G',
#  array([[-0.5 ,  0.5 ],
#         [-0.75,  0.25]]))
